# %% [markdown]
# **SPDX-License-Identifier:** LGPL-3.0-or-later
#
# **Name:** Formatting MGS I sweep output for creating contour plots
# **Description:** The Python script for formatting MGS I sweep output for creating contour plots.
# **Author:** Garry Sotnik
#
# Import library

# %%
import pandas as pd

# %%
df = pd.read_csv('sweep_0.1-0.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = pd.read_csv('final.csv')
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_0.6-1.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_1.1-1.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_1.6-2.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_2.1-2.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_2.6-3.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_3.1-3.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_3.6-4.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_4.1-4.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_4.6-5.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_5.1-5.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_5.6-6.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_6.1-6.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_6.6-7.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_7.1-7.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_7.6-8.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_8.1-8.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_8.6-9.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_9.1-9.5.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)

df = pd.read_csv('sweep_9.6-10.0.csv', skiprows=18)
df = df.drop(columns=['x', 'x.1', 'x.2', 'color', 'color.1', 'color.2', 'pen down?','pen down?.1', 'pen down?.2'])
df = df.drop_duplicates()
fdf = fdf.append(df, ignore_index=True)
fdf = fdf.drop_duplicates()
fdf = fdf.to_csv('final.csv', index=False)
